# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\abhay jha\OneDrive\Desktop\Airbnb\airbnb_v2.csv")
df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'rating', 'reviews', 'host_name', 'host_id',
#        'address', 'features', 'amenities', 'safety_rules', 'hourse_rules',
#        'img_links', 'price', 'country', 'bathrooms', 'beds', 'guests',
#        'toiles', 'bedrooms', 'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
# Average price of Airbnb in every country 

#in this type of question we use groupby
#Groupby = We use groupby when we want to divide a large dataset into smaller groups based on some column and then perform calculations like sum, average, or count on each group.

df.groupby('country')['price'].mean().sort_values(ascending = True)
# Out:
# country
#  Senegal                   1289.000000
# Jordan                     1812.000000
# Georgia                    1906.333333
# Cuba                       2276.500000
#  Bolivia                   2462.000000
#                              ...
#  Qatar                   112717.500000
#  Bahamas                 116397.500000
#  United Arab Emirates    119633.653846
#  Honduras                140998.500000
#  Seychelles              155225.111111
# Name: price, Length: 148, dtype: float64

# %%
# 2 Top 10 country with maximum number of airbnbs

# %%
# to find the country first of all clean the data sets

df['country']
# Out:
# 0              Turkey
# 1              Turkey
# 2             Georgia
# 3              Turkey
# 4              Turkey
#              ...
# 12800     South Korea
# 12801       Indonesia
# 12802          Uganda
# 12803       Indonesia
# 12804           Japan
# Name: country, Length: 12805, dtype: object

# %%
# as we see there is duplicate value in country column so now we remove them 

df['country'].unique()
# Out:
# array([' Turkey', ' Georgia', ' Vietnam', ' Thailand', ' South Korea',
#        ' India', ' Philippines', ' Japan', ' Lebanon', ' Taiwan',
#        ' Israel', 'Turkey', ' Armenia', ' Cyprus', ' Lithuania',
#        ' Slovakia', ' Denmark', ' Germany', ' Indonesia', ' Poland',
#        ' Romania', ' Greece', ' Ukraine', ' Hungary', ' Albania',
#        ' Bulgaria', ' Malaysia', ' Montenegro', ' Slovenia', ' Czechia',
#        ' Sweden', ' Austria', ' Croatia', ' Tanzania', ' Italy',
#        ' Sri Lanka', 'Philippines', ' Bosnia & Herzegovina', 'Montenegro',
#        ' Kenya', ' Serbia', ' Seychelles', ' Finland', ' Norway',
#        ' Iceland', ' Greenland', ' United States', ' Canada',
#        ' Svalbard & Jan Mayen', 'Iceland', ' France', ' Australia',
#        ' Morocco', ' Egypt', ' South Africa', ' Spain',
#        ' United Arab Emirates', ' United Kingdom', ' Pakistan',
#        'Thailand', ' Nepal', 'Sri Lanka', ' Singapore', ' Cambodia',
# ...

# %%
# here we have multiple country with same name but some of them have space or some of them have not 

df['country'] = df['country'].str.strip()
df['country'].unique()

# after using this my data set is clear
# Out:
# array(['Turkey', 'Georgia', 'Vietnam', 'Thailand', 'South Korea', 'India',
#        'Philippines', 'Japan', 'Lebanon', 'Taiwan', 'Israel', 'Armenia',
#        'Cyprus', 'Lithuania', 'Slovakia', 'Denmark', 'Germany',
#        'Indonesia', 'Poland', 'Romania', 'Greece', 'Ukraine', 'Hungary',
#        'Albania', 'Bulgaria', 'Malaysia', 'Montenegro', 'Slovenia',
#        'Czechia', 'Sweden', 'Austria', 'Croatia', 'Tanzania', 'Italy',
#        'Sri Lanka', 'Bosnia & Herzegovina', 'Kenya', 'Serbia',
#        'Seychelles', 'Finland', 'Norway', 'Iceland', 'Greenland',
#        'United States', 'Canada', 'Svalbard & Jan Mayen', 'France',
#        'Australia', 'Morocco', 'Egypt', 'South Africa', 'Spain',
#        'United Arab Emirates', 'United Kingdom', 'Pakistan', 'Nepal',
#        'Singapore', 'Cambodia', 'Azerbaijan', 'Estonia', 'Latvia',
#        'Costa Rica', 'Netherlands', 'Portugal', 'New Zealand', 'Panama',
#        'Mexico', 'Peru', 'Chile', 'Belize', 'Colombia', 'Switzerland',
# ...

# %%
#3 Host with maximum number of airbnbs listed

df['host_id'].value_counts()
# Out:
# host_id
# 157378426.0    28
# 262573392.0    13
# 45788344.0     13
# 156292477.0    13
# 95903847.0     12
#                ..
# 385223440.0     1
# 90542732.0      1
# 281370526.0     1
# 430105736.0     1
# 441844482.0     1
# Name: count, Length: 10375, dtype: int64

# %%
df[df['host_id'] == 157378426.0]
# Out:
#        Unnamed: 0                  id  \
# 1190         1190  601816645157829673
# 1544         1544  628897626500350545
# 1557         1557            45644216
# 1561         1561  636631343388002719
# 1571         1571  614293947503916670
# 1614         1614  616569469785545211
# 3080         3080            52505611
# 3142         3142            52162851
# 5276         5276  578733555164036351
# 5284         5284  669002665572906395
# 5311         5311  635983225003873129
# 5338         5338  635988696145613565
# 5339         5339  635980238448301348
# 5347         5347            52118069
# 5356         5356  607847688839094950
# 5370         5370            52982244
# 7506         7506  608314604315148888
# 7507         7507  611451448071031676
# 7509         7509            47823653
# 7513         7513            38209396
# 7516         7516            52981779
# 7553         7553  682374742583806642
# 7630         7630  662657516819710285
# ...

# %%
# here we check maxium number of hosts in that code then after we were checking if there is dulpicacy or not in that host column 

df.duplicated('id')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12800    False
# 12801    False
# 12802    False
# 12803    False
# 12804    False
# Length: 12805, dtype: bool

# %%
df.duplicated('id').sum()

# after using this duplicated functions to check whether there is duplicacy or not
# Out:
# np.int64(0)

# %%
df.isnull().sum()

# i this code we were checking there is airbnb or not in dataset 
# we can also delete the unnecessary column from the table so we remove check in ,checkout and unnamed .
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
del df['checkin']
del df['checkout']
del df['Unnamed: 0']

# after using delete function we check this there is null value in dataframe or not so we repeat the previous code in next line

# %%
df.isnull().sum()

# after using this code we see there is no null value in dataframe
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       8
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# country         0
# bathrooms       0
# beds            0
# guests          0
# toiles          0
# bedrooms        0
# studios         0
# dtype: int64

# %%
df['host_name'].fillna('Not Available',inplace = True)
# Out:
# C:\Users\abhay jha\AppData\Local\Temp\ipykernel_9540\3315632323.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['host_name'].fillna('Not Available',inplace = True)

# %%
df.isnull().sum()


# after using this two previous code we were seeing that we successfully remove the null value from host name
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# country         0
# bathrooms       0
# beds            0
# guests          0
# toiles          0
# bedrooms        0
# studios         0
# dtype: int64

# %%
#4 Most popular country to host an airbnb

df.groupby('country')['id'].count().sort_values(ascending = False).head(1)
# Out:
# country
# India    2779
# Name: id, dtype: int64

# %%
df_1 = pd.read_csv(r"C:\Users\abhay jha\OneDrive\Desktop\Airbnb\airbnb_v2.csv")
df_1.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
# import pandas as pd
df_2 = pd.read_csv(r"C:\Users\abhay jha\OneDrive\Desktop\Airbnb\airbnb.csv")
df_2.head()
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New     NaN
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New     NaN
#
#                                host_name      host_id  \
# 0    Entire bungalow hosted by Mehmetcan  357334205.0
# 1           Entire villa hosted by Fatih  386223873.0
# 2          Entire cabin hosted by Giorgi  409690853.0
# 3        Entire bungalow hosted by Melih  401873242.0
# 4  Entire bungalow hosted by Arp Sapanca  414884116.0
#
#                     address                                features  \
# 0  Kartepe, Kocaeli, Turkey    2 guests,2 bedrooms,1 bed,1 bathroom
# ...
